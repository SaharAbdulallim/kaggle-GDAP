# %% [markdown]
# # Wheat Disease Classification
# Texture + spectral + cross-modal features | LightGBM | Pseudo-labeling | Optuna HPO

# %% [markdown]
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2

import os
import numpy as np
from sklearn.metrics import classification_report

from src.config import CFG
from src.data import load_train, load_test
from src.features import extract_batch
from src.optimize import (
    get_feature_importance, evaluate, run_optimization,
    train_final, predict, generate_pseudo_labels,
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Configuration

# %%
cfg = CFG()
cfg.OPTUNA_TRIALS = 80
cfg.CV_FOLDS = 5
cfg.N_TOP_FEATURES = 120
print(f"Trials: {cfg.OPTUNA_TRIALS}, Folds: {cfg.CV_FOLDS}, Top features: {cfg.N_TOP_FEATURES}")
print(f"Pseudo threshold: {cfg.PSEUDO_THRESHOLD}, Pseudo weight: {cfg.PSEUDO_WEIGHT}")
# Out:
# Trials: 80, Folds: 5, Top features: 120
# Pseudo threshold: 0.75, Pseudo weight: 0.41

# %% [markdown]
# ## Load Data

# %%
samples, labels = load_train(cfg)
test_samples = load_test(cfg)
counts = dict(zip(*np.unique(labels, return_counts=True)))
print(f"Train: {len(samples)} samples | {counts}")
print(f"Test:  {len(test_samples)} samples")
# Out:
# Train: 577 samples | {np.int64(0): np.int64(191), np.int64(1): np.int64(186), np.int64(2): np.int64(200)}
# Test:  300 samples

# %% [markdown]
# ## Feature Extraction

# %%
X_all = extract_batch(samples)
X_test_all = extract_batch(test_samples)
print(f"Train features: {X_all.shape}")
print(f"Test features:  {X_test_all.shape}")
# Out:
# Train features: (577, 1262)
# Test features:  (300, 1262)

# %% [markdown]
# ## Feature Selection

# %%
top_idx = get_feature_importance(X_all, labels, cfg)
X = X_all[:, top_idx[:cfg.N_TOP_FEATURES]]
X_test = X_test_all[:, top_idx[:cfg.N_TOP_FEATURES]]
print(f"Selected top {cfg.N_TOP_FEATURES} -> train: {X.shape}, test: {X_test.shape}")
# Out:
# Selected top 120 -> train: (577, 120), test: (300, 120)

# %% [markdown]
# ## Pseudo-Labeling

# %%
preds, conf, mask = generate_pseudo_labels(X, labels, X_test, cfg)
X_pseudo = X_test[mask]
y_pseudo = preds[mask]
dist = np.bincount(y_pseudo, minlength=3)
print(f"Pseudo-labels: {mask.sum()}/{len(X_test)} (threshold={cfg.PSEUDO_THRESHOLD})")
print(f"Distribution: H={dist[0]}, O={dist[1]}, R={dist[2]}")
# Out:
# Pseudo-labels: 222/300 (threshold=0.75)
# Distribution: H=59, O=82, R=81

# %% [markdown]
# ## Optuna HPO
# Set `RUN_OPTUNA = False` to skip and use saved defaults.

# %%
RUN_OPTUNA = True

if RUN_OPTUNA:
    result = run_optimization(X, labels, cfg, X_pseudo=X_pseudo, y_pseudo=y_pseudo)
    cfg.LGB_PARAMS = result["params"]
    cfg.HEALTH_WEIGHT = result["health_weight"]
    cfg.PSEUDO_WEIGHT = result.get("pseudo_weight", cfg.PSEUDO_WEIGHT)
    print(f"Best F1: {result['best_f1']:.4f}")
    print(f"Params: {cfg.LGB_PARAMS}")
    print(f"Health weight: {cfg.HEALTH_WEIGHT:.2f}, Pseudo weight: {cfg.PSEUDO_WEIGHT:.2f}")
else:
    print("Skipping Optuna, using default params from config")
    print(f"Params: {cfg.LGB_PARAMS}")
    print(f"Health weight: {cfg.HEALTH_WEIGHT}, Pseudo weight: {cfg.PSEUDO_WEIGHT}")
# Out:
# [I 2026-02-07 17:39:27,207] A new study created in memory with name: no-name-5c01ab2c-c7db-47d3-a14a-d8eb00588405
# [I 2026-02-07 17:39:36,233] Trial 0 finished with value: 0.7728437934419176 and parameters: {'n_estimators': 1249, 'max_depth': 8, 'learning_rate': 0.03082649433960295, 'subsample': 0.6693963178886665, 'colsample_bytree': 0.37800932022121825, 'min_child_samples': 17, 'reg_alpha': 0.07081203049440488, 'reg_lambda': 8.970410111823023, 'num_leaves': 33, 'health_weight': 2.416145155592091, 'pseudo_weight': 0.1185260448662222}. Best is trial 0 with value: 0.7728437934419176.
# [I 2026-02-07 17:39:48,987] Trial 1 finished with value: 0.7890145383273572 and parameters: {'n_estimators': 2440, 'max_depth': 7, 'learning_rate': 0.008474662085622163, 'subsample': 0.4818212352431953, 'colsample_bytree': 0.3917022549267169, 'min_child_samples': 25, 'reg_alpha': 1.159892446676645, 'reg_lambda': 0.6651458041089254, 'num_leaves': 20, 'health_weight': 2.223705789444759, 'pseudo_weight': 0.22554447458683766}. Best is trial 1 with value: 0.7890145383273572.
# [I 2026-02-07 17:39:54,351] Trial 2 finished with value: 0.7780188561071453 and parameters: {'n_estimators': 1084, 'max_depth': 5, 'learning_rate': 0.015529310666912379, 'subsample': 0.7533291826268561, 'colsample_bytree': 0.39983689107917986, 'min_child_samples': 36, 'reg_alpha': 1.7396755198181189, 'reg_lambda': 0.06604451645744491, 'num_leaves': 34, 'health_weight': 1.341048247374583, 'pseudo_weight': 0.1585464336867516}. Best is trial 1 with value: 0.7890145383273572.
# [I 2026-02-07 17:39:56,969] Trial 3 finished with value: 0.7702179580745881 and parameters: {'n_estimators': 2398, 'max_depth': 8, 'learning_rate': 0.03727153350377881, 'subsample': 0.5370761961280168, 'colsample_bytree': 0.3488360570031919, 'min_child_samples': 44, 'reg_alpha': 0.698671774090497, 'reg_lambda': 0.10387733822313477, 'num_leaves': 29, 'health_weight': 1.0687770422304368, 'pseudo_weight': 0.9183883618709039}. Best is trial 1 with value: 0.7890145383273572.
# [I 2026-02-07 17:40:02,174] Trial 4 finished with value: 0.7010200845818519 and parameters: {'n_estimators': 1017, 'max_depth': 6, 'learning_rate': 0.010848326605904336, 'subsample': 0.6340306095300149, 'colsample_bytree': 0.5733551396716399, 'min_child_samples': 19, 'reg_alpha': 16.668148938546906, 'reg_lambda': 5.198907757624559, 'num_leaves': 48, 'health_weight': 2.789654700855298, 'pseudo_weight': 0.6381099809299766}. Best is trial 1 with value: 0.7890145383273572.
# [I 2026-02-07 17:40:11,971] Trial 5 finished with value: 0.7822846636054672 and parameters: {'n_estimators': 2344, 'max_depth': 3, 'learning_rate': 0.008137125870512886, 'subsample': 0.4203522800097422, 'colsample_bytree': 0.46266516538163216, 'min_child_samples': 29, 'reg_alpha': 0.25411860559533894, 'reg_lambda': 7.167945922774421, 'num_leaves': 23, 'health_weight': 1.5618690193747615, 'pseudo_weight': 0.5884264748424236}. Best is trial 1 with value: 0.7890145383273572.
# [I 2026-02-07 17:40:24,356] Trial 6 finished with value: 0.7651964006380819 and parameters: {'n_estimators': 781, 'max_depth': 7, 'learning_rate': 0.00601760477753102, 'subsample': 0.8440991214702327, 'colsample_bytree': 0.6861223846483286, 'min_child_samples': 20, 'reg_alpha': 0.05168194914407149, 'reg_lambda': 6.6198715376193356, 'num_leaves': 38, 'health_weight': 2.4580143360819746, 'pseudo_weight': 0.7941433120173511}. Best is trial 1 with value: 0.7890145383273572.
# [I 2026-02-07 17:40:31,751] Trial 7 finished with value: 0.7856744670228613 and parameters: {'n_estimators': 648, 'max_depth': 5, 'learning_rate': 0.006668278355230079, 'subsample': 0.7883965416440171, 'colsample_bytree': 0.611649063413779, 'min_child_samples': 26, 'reg_alpha': 0.07317330054950068, 'reg_lambda': 0.3222290283126465, 'num_leaves': 21, 'health_weight': 2.459212356676128, 'pseudo_weight': 0.6738017242196918}. Best is trial 1 with value: 0.7890145383273572.
# [I 2026-02-07 17:40:43,407] Trial 8 finished with value: 0.7661198899527923 and parameters: {'n_estimators': 2275, 'max_depth': 5, 'learning_rate': 0.0067302914542500996, 'subsample': 0.7209601542503478, 'colsample_bytree': 0.6803925243084488, 'min_child_samples': 38, 'reg_alpha': 5.070757689650246, 'reg_lambda': 0.9635089863260423, 'num_leaves': 30, 'health_weight': 1.8550820367170993, 'pseudo_weight': 0.12287721406968567}. Best is trial 1 with value: 0.7890145383273572.
# [I 2026-02-07 17:40:45,884] Trial 9 finished with value: 0.7689885387639948 and parameters: {'n_estimators': 715, 'max_depth': 3, 'learning_rate': 0.024309284981694938, 'subsample': 0.541460191484347, 'colsample_bytree': 0.5542853455823513, 'min_child_samples': 56, 'reg_alpha': 0.22266058202121738, 'reg_lambda': 0.5845356314008853, 'num_leaves': 40, 'health_weight': 1.457596330983245, 'pseudo_weight': 0.1692819188459137}. Best is trial 1 with value: 0.7890145383273572.
# [I 2026-02-07 17:40:47,423] Trial 10 finished with value: 0.7678809251963867 and parameters: {'n_estimators': 1079, 'max_depth': 3, 'learning_rate': 0.05038279718068964, 'subsample': 0.7636541708039877, 'colsample_bytree': 0.6167018782552117, 'min_child_samples': 54, 'reg_alpha': 6.168406154131421, 'reg_lambda': 0.15291021189909665, 'num_leaves': 46, 'health_weight': 2.078684483831301, 'pseudo_weight': 0.8266961396476563}. Best is trial 1 with value: 0.7890145383273572.
# [I 2026-02-07 17:40:55,641] Trial 11 finished with value: 0.7541196847245436 and parameters: {'n_estimators': 2293, 'max_depth': 4, 'learning_rate': 0.006572581459366494, 'subsample': 0.5025708231438738, 'colsample_bytree': 0.5135538943131281, 'min_child_samples': 51, 'reg_alpha': 8.682456544212515, 'reg_lambda': 0.052126655980929616, 'num_leaves': 29, 'health_weight': 1.834822006297558, 'pseudo_weight': 0.29989702942365726}. Best is trial 1 with value: 0.7890145383273572.
# [I 2026-02-07 17:40:59,211] Trial 12 finished with value: 0.7873251981995295 and parameters: {'n_estimators': 739, 'max_depth': 5, 'learning_rate': 0.05206435272434695, 'subsample': 0.5454413194093398, 'colsample_bytree': 0.559395310871683, 'min_child_samples': 45, 'reg_alpha': 0.44172913450348306, 'reg_lambda': 16.889052358474252, 'num_leaves': 49, 'health_weight': 1.5035645916507283, 'pseudo_weight': 0.547523655303147}. Best is trial 1 with value: 0.7890145383273572.
# [I 2026-02-07 17:41:11,347] Trial 13 finished with value: 0.7803807873325217 and parameters: {'n_estimators': 1102, 'max_depth': 4, 'learning_rate': 0.005479964008825365, 'subsample': 0.6743039502909536, 'colsample_bytree': 0.5513395116144307, 'min_child_samples': 12, 'reg_alpha': 0.26547572814287823, 'reg_lambda': 11.543362328106205, 'num_leaves': 18, 'health_weight': 1.2897897441824462, 'pseudo_weight': 0.5405074842498068}. Best is trial 1 with value: 0.7890145383273572.
# [I 2026-02-07 17:41:15,514] Trial 14 finished with value: 0.775289003937967 and parameters: {'n_estimators': 2472, 'max_depth': 4, 'learning_rate': 0.026565994714204802, 'subsample': 0.7427288268979229, 'colsample_bytree': 0.4188187719961998, 'min_child_samples': 47, 'reg_alpha': 0.45285980943450793, 'reg_lambda': 2.209366213939139, 'num_leaves': 35, 'health_weight': 2.071549368149517, 'pseudo_weight': 0.18126079304896747}. Best is trial 1 with value: 0.7890145383273572.
# [I 2026-02-07 17:41:22,715] Trial 15 finished with value: 0.780402377188538 and parameters: {'n_estimators': 1783, 'max_depth': 7, 'learning_rate': 0.017207210903189916, 'subsample': 0.4436155062507567, 'colsample_bytree': 0.3080302849039205, 'min_child_samples': 31, 'reg_alpha': 2.3515384362831853, 'reg_lambda': 2.2856555588455656, 'num_leaves': 10, 'health_weight': 2.9349966971027595, 'pseudo_weight': 0.43578143104221884}. Best is trial 1 with value: 0.7890145383273572.
# [I 2026-02-07 17:41:30,861] Trial 16 finished with value: 0.7761804626232844 and parameters: {'n_estimators': 1738, 'max_depth': 6, 'learning_rate': 0.011842315104658363, 'subsample': 0.5799027081273748, 'colsample_bytree': 0.7677809380407123, 'min_child_samples': 60, 'reg_alpha': 1.2978640933180048, 'reg_lambda': 2.5571278745017407, 'num_leaves': 13, 'health_weight': 1.7012600165718963, 'pseudo_weight': 0.3895904598402382}. Best is trial 1 with value: 0.7890145383273572.
# [I 2026-02-07 17:41:32,959] Trial 17 finished with value: 0.7716290520009751 and parameters: {'n_estimators': 1889, 'max_depth': 7, 'learning_rate': 0.05768502836739513, 'subsample': 0.46585057577613603, 'colsample_bytree': 0.4851276596367884, 'min_child_samples': 42, 'reg_alpha': 0.5950759656549428, 'reg_lambda': 0.3259458844567813, 'num_leaves': 43, 'health_weight': 2.295700942302677, 'pseudo_weight': 0.3022059308213879}. Best is trial 1 with value: 0.7890145383273572.
# [I 2026-02-07 17:41:49,514] Trial 18 finished with value: 0.7883927842929342 and parameters: {'n_estimators': 1449, 'max_depth': 6, 'learning_rate': 0.010314948136095558, 'subsample': 0.5913191678204773, 'colsample_bytree': 0.44736741444966555, 'min_child_samples': 23, 'reg_alpha': 3.089580027657917, 'reg_lambda': 19.88209029392896, 'num_leaves': 16, 'health_weight': 1.1446805657869745, 'pseudo_weight': 0.4599826294453434}. Best is trial 1 with value: 0.7890145383273572.
# [I 2026-02-07 17:41:59,264] Trial 19 finished with value: 0.7836458849294907 and parameters: {'n_estimators': 1489, 'max_depth': 6, 'learning_rate': 0.010876387363311136, 'subsample': 0.5994621043867071, 'colsample_bytree': 0.4536263536042336, 'min_child_samples': 25, 'reg_alpha': 3.045991722499497, 'reg_lambda': 1.0078593099135955, 'num_leaves': 16, 'health_weight': 1.1461933603952394, 'pseudo_weight': 0.2857182072269034}. Best is trial 1 with value: 0.7890145383273572.
# [I 2026-02-07 17:42:11,247] Trial 20 finished with value: 0.7873039095270447 and parameters: {'n_estimators': 2019, 'max_depth': 7, 'learning_rate': 0.009257987511682214, 'subsample': 0.4766659636892878, 'colsample_bytree': 0.31185502024624984, 'min_child_samples': 10, 'reg_alpha': 3.460449080456476, 'reg_lambda': 4.005384798913397, 'num_leaves': 8, 'health_weight': 2.217916560799209, 'pseudo_weight': 0.45029974712666054}. Best is trial 1 with value: 0.7890145383273572.
# [I 2026-02-07 17:42:22,732] Trial 21 finished with value: 0.793284220345525 and parameters: {'n_estimators': 1506, 'max_depth': 6, 'learning_rate': 0.014777493130428204, 'subsample': 0.5429031021764313, 'colsample_bytree': 0.428353469484714, 'min_child_samples': 33, 'reg_alpha': 0.8684581885773155, 'reg_lambda': 16.239136092354588, 'num_leaves': 24, 'health_weight': 1.2193080009664772, 'pseudo_weight': 0.5114200663823955}. Best is trial 21 with value: 0.793284220345525.
# [I 2026-02-07 17:42:36,619] Trial 22 finished with value: 0.7949257621893536 and parameters: {'n_estimators': 1503, 'max_depth': 6, 'learning_rate': 0.014080611495692182, 'subsample': 0.502764794689926, 'colsample_bytree': 0.43670099521750017, 'min_child_samples': 32, 'reg_alpha': 1.2075371441431133, 'reg_lambda': 18.981596480921983, 'num_leaves': 24, 'health_weight': 1.0570822315995823, 'pseudo_weight': 0.3851517264756046}. Best is trial 22 with value: 0.7949257621893536.
# [I 2026-02-07 17:42:45,008] Trial 23 finished with value: 0.7800243441951147 and parameters: {'n_estimators': 2059, 'max_depth': 7, 'learning_rate': 0.013399374511705385, 'subsample': 0.4011618453390877, 'colsample_bytree': 0.36863110128679555, 'min_child_samples': 32, 'reg_alpha': 1.1095641485853927, 'reg_lambda': 1.1466245797877557, 'num_leaves': 24, 'health_weight': 1.0232419232551058, 'pseudo_weight': 0.34425616705009676}. Best is trial 22 with value: 0.7949257621893536.
# [I 2026-02-07 17:42:53,093] Trial 24 finished with value: 0.783334350779876 and parameters: {'n_estimators': 1596, 'max_depth': 8, 'learning_rate': 0.022043950172661326, 'subsample': 0.506194400752356, 'colsample_bytree': 0.498328459968943, 'min_child_samples': 38, 'reg_alpha': 0.8359510384321582, 'reg_lambda': 14.648166038618754, 'num_leaves': 25, 'health_weight': 1.2594529463294688, 'pseudo_weight': 0.23882159880673903}. Best is trial 22 with value: 0.7949257621893536.
# [I 2026-02-07 17:42:58,743] Trial 25 finished with value: 0.781691826650929 and parameters: {'n_estimators': 1343, 'max_depth': 6, 'learning_rate': 0.019530551760349672, 'subsample': 0.5036127794293268, 'colsample_bytree': 0.4203538805551276, 'min_child_samples': 29, 'reg_alpha': 1.4743077335577532, 'reg_lambda': 0.43518409303829986, 'num_leaves': 20, 'health_weight': 2.670126781058892, 'pseudo_weight': 0.3990810196126857}. Best is trial 22 with value: 0.7949257621893536.
# [I 2026-02-07 17:43:03,990] Trial 26 finished with value: 0.7870634367905562 and parameters: {'n_estimators': 2137, 'max_depth': 7, 'learning_rate': 0.014008436080878896, 'subsample': 0.46427156994413077, 'colsample_bytree': 0.342552469460493, 'min_child_samples': 34, 'reg_alpha': 0.1721525528713384, 'reg_lambda': 0.1971211662502389, 'num_leaves': 26, 'health_weight': 1.7300522273439545, 'pseudo_weight': 0.49835695991688755}. Best is trial 22 with value: 0.7949257621893536.
# [I 2026-02-07 17:43:19,047] Trial 27 finished with value: 0.7884141261363302 and parameters: {'n_estimators': 1604, 'max_depth': 6, 'learning_rate': 0.008436470742012814, 'subsample': 0.5677694919671838, 'colsample_bytree': 0.3978080266071835, 'min_child_samples': 15, 'reg_alpha': 1.9149160354472237, 'reg_lambda': 3.6876934223217597, 'num_leaves': 13, 'health_weight': 1.956124358900659, 'pseudo_weight': 0.22120185737667525}. Best is trial 22 with value: 0.7949257621893536.
# [I 2026-02-07 17:43:23,582] Trial 28 finished with value: 0.7825076837580655 and parameters: {'n_estimators': 510, 'max_depth': 8, 'learning_rate': 0.018592991265526566, 'subsample': 0.636773733568492, 'colsample_bytree': 0.517710798011912, 'min_child_samples': 40, 'reg_alpha': 0.3845637594466604, 'reg_lambda': 1.433533252121258, 'num_leaves': 27, 'health_weight': 1.6251191318496947, 'pseudo_weight': 0.35635420354714437}. Best is trial 22 with value: 0.7949257621893536.
# [I 2026-02-07 17:43:28,843] Trial 29 finished with value: 0.7972735893591449 and parameters: {'n_estimators': 1280, 'max_depth': 7, 'learning_rate': 0.03464875442912374, 'subsample': 0.5025457717112095, 'colsample_bytree': 0.36801231137182827, 'min_child_samples': 27, 'reg_alpha': 0.12062677244634375, 'reg_lambda': 9.457309928722777, 'num_leaves': 21, 'health_weight': 1.4103423584370167, 'pseudo_weight': 0.7067889548609452}. Best is trial 29 with value: 0.7972735893591449.
# [I 2026-02-07 17:43:36,047] Trial 30 finished with value: 0.7949080810703048 and parameters: {'n_estimators': 1272, 'max_depth': 8, 'learning_rate': 0.03157779987869202, 'subsample': 0.5236051810603279, 'colsample_bytree': 0.3546845001782458, 'min_child_samples': 22, 'reg_alpha': 0.12035446083442639, 'reg_lambda': 10.282580405982113, 'num_leaves': 32, 'health_weight': 1.3668423772833025, 'pseudo_weight': 0.7075740141262681}. Best is trial 29 with value: 0.7972735893591449.
# [I 2026-02-07 17:43:43,025] Trial 31 finished with value: 0.7970503433607398 and parameters: {'n_estimators': 1277, 'max_depth': 8, 'learning_rate': 0.03572221669393343, 'subsample': 0.5279427199514929, 'colsample_bytree': 0.34844271129602106, 'min_child_samples': 21, 'reg_alpha': 0.09013162358960493, 'reg_lambda': 10.801592621860774, 'num_leaves': 32, 'health_weight': 1.4071366607177147, 'pseudo_weight': 0.7224263051042299}. Best is trial 29 with value: 0.7972735893591449.
# [I 2026-02-07 17:43:49,040] Trial 32 finished with value: 0.7951106516605079 and parameters: {'n_estimators': 1244, 'max_depth': 8, 'learning_rate': 0.036310604619614335, 'subsample': 0.5123390118117402, 'colsample_bytree': 0.3495672873566993, 'min_child_samples': 22, 'reg_alpha': 0.1200663946209115, 'reg_lambda': 9.837699982972545, 'num_leaves': 31, 'health_weight': 1.3936774155620995, 'pseudo_weight': 0.7224386584371262}. Best is trial 29 with value: 0.7972735893591449.
# [I 2026-02-07 17:43:54,439] Trial 33 finished with value: 0.7937321713002691 and parameters: {'n_estimators': 1213, 'max_depth': 8, 'learning_rate': 0.03989605582356309, 'subsample': 0.4476168393225538, 'colsample_bytree': 0.3232555247501476, 'min_child_samples': 16, 'reg_alpha': 0.0998476285660708, 'reg_lambda': 8.786916750484624, 'num_leaves': 35, 'health_weight': 1.4113417774135704, 'pseudo_weight': 0.7733589724190018}. Best is trial 29 with value: 0.7972735893591449.
# [I 2026-02-07 17:43:59,559] Trial 34 finished with value: 0.7873119125861103 and parameters: {'n_estimators': 921, 'max_depth': 8, 'learning_rate': 0.03811942268904992, 'subsample': 0.4868496220843113, 'colsample_bytree': 0.3785955959902747, 'min_child_samples': 27, 'reg_alpha': 0.13368960629752016, 'reg_lambda': 10.113069471675828, 'num_leaves': 32, 'health_weight': 1.0126788783975447, 'pseudo_weight': 0.895924257409578}. Best is trial 29 with value: 0.7972735893591449.
# [I 2026-02-07 17:44:05,252] Trial 35 finished with value: 0.7887275975043203 and parameters: {'n_estimators': 1376, 'max_depth': 7, 'learning_rate': 0.03192962143123409, 'subsample': 0.5634675446998197, 'colsample_bytree': 0.3359846958966291, 'min_child_samples': 20, 'reg_alpha': 0.07400564491805287, 'reg_lambda': 5.888002466863687, 'num_leaves': 29, 'health_weight': 1.1757312545360064, 'pseudo_weight': 0.992574746320626}. Best is trial 29 with value: 0.7972735893591449.
# [I 2026-02-07 17:44:09,214] Trial 36 finished with value: 0.7955819785141196 and parameters: {'n_estimators': 1200, 'max_depth': 8, 'learning_rate': 0.04357618844121199, 'subsample': 0.6183901586469598, 'colsample_bytree': 0.39142812587796005, 'min_child_samples': 23, 'reg_alpha': 0.18163751053671492, 'reg_lambda': 4.22888892580402, 'num_leaves': 38, 'health_weight': 1.5878431778019788, 'pseudo_weight': 0.6005231086704943}. Best is trial 29 with value: 0.7972735893591449.
# [I 2026-02-07 17:44:14,119] Trial 37 finished with value: 0.7930947481564609 and parameters: {'n_estimators': 946, 'max_depth': 8, 'learning_rate': 0.04443855614169726, 'subsample': 0.6722760776950261, 'colsample_bytree': 0.38946424038120236, 'min_child_samples': 18, 'reg_alpha': 0.17554889045196792, 'reg_lambda': 4.688202017395746, 'num_leaves': 39, 'health_weight': 1.5418786567159068, 'pseudo_weight': 0.6276702702578203}. Best is trial 29 with value: 0.7972735893591449.
# [I 2026-02-07 17:44:18,820] Trial 38 finished with value: 0.7961839202343298 and parameters: {'n_estimators': 1212, 'max_depth': 8, 'learning_rate': 0.02848118614342151, 'subsample': 0.6042459388651417, 'colsample_bytree': 0.3681258814434105, 'min_child_samples': 22, 'reg_alpha': 0.09386114592447117, 'reg_lambda': 3.2632381855513786, 'num_leaves': 36, 'health_weight': 1.3728175034412793, 'pseudo_weight': 0.7452915074322176}. Best is trial 29 with value: 0.7972735893591449.
# [I 2026-02-07 17:44:25,629] Trial 39 finished with value: 0.7835363811333268 and parameters: {'n_estimators': 1169, 'max_depth': 8, 'learning_rate': 0.028391706001821417, 'subsample': 0.6185974541868249, 'colsample_bytree': 0.30364528895178056, 'min_child_samples': 13, 'reg_alpha': 0.05091888860740563, 'reg_lambda': 3.2879350542672627, 'num_leaves': 36, 'health_weight': 1.6421106820032048, 'pseudo_weight': 0.6066031025426729}. Best is trial 29 with value: 0.7972735893591449.
# [I 2026-02-07 17:44:30,018] Trial 40 finished with value: 0.7908554828023255 and parameters: {'n_estimators': 855, 'max_depth': 7, 'learning_rate': 0.04422047165580581, 'subsample': 0.6968129544310573, 'colsample_bytree': 0.4767683694416216, 'min_child_samples': 27, 'reg_alpha': 0.08503783786953956, 'reg_lambda': 7.400192476576387, 'num_leaves': 42, 'health_weight': 1.8191380998376696, 'pseudo_weight': 0.7573265779799168}. Best is trial 29 with value: 0.7972735893591449.
# [I 2026-02-07 17:44:35,429] Trial 41 finished with value: 0.7947823168639819 and parameters: {'n_estimators': 1274, 'max_depth': 8, 'learning_rate': 0.03576836810435117, 'subsample': 0.6113591518712969, 'colsample_bytree': 0.3724991857435233, 'min_child_samples': 23, 'reg_alpha': 0.13536391512759907, 'reg_lambda': 5.608535179983288, 'num_leaves': 37, 'health_weight': 1.3805849456677854, 'pseudo_weight': 0.6986742168748967}. Best is trial 29 with value: 0.7972735893591449.
# [I 2026-02-07 17:44:42,107] Trial 42 finished with value: 0.7933620477603325 and parameters: {'n_estimators': 1082, 'max_depth': 8, 'learning_rate': 0.03350314938951719, 'subsample': 0.6440738956522356, 'colsample_bytree': 0.3481539701949714, 'min_child_samples': 21, 'reg_alpha': 0.06370188288112169, 'reg_lambda': 12.758582138576557, 'num_leaves': 31, 'health_weight': 1.4513683727651119, 'pseudo_weight': 0.8415497930162876}. Best is trial 29 with value: 0.7972735893591449.
# [I 2026-02-07 17:44:47,032] Trial 43 finished with value: 0.7947295822102132 and parameters: {'n_estimators': 1373, 'max_depth': 8, 'learning_rate': 0.043216575777522144, 'subsample': 0.5238765874744731, 'colsample_bytree': 0.40429424707318484, 'min_child_samples': 18, 'reg_alpha': 0.1982330872653755, 'reg_lambda': 7.648814209776836, 'num_leaves': 34, 'health_weight': 1.3268590484156353, 'pseudo_weight': 0.7335401431520194}. Best is trial 29 with value: 0.7972735893591449.
# [I 2026-02-07 17:44:51,725] Trial 44 finished with value: 0.8026199598993928 and parameters: {'n_estimators': 1151, 'max_depth': 8, 'learning_rate': 0.02644920783509296, 'subsample': 0.5621719321714961, 'colsample_bytree': 0.37077023223719513, 'min_child_samples': 29, 'reg_alpha': 0.2878939287635039, 'reg_lambda': 1.673359089746224, 'num_leaves': 41, 'health_weight': 1.5628352207737086, 'pseudo_weight': 0.6748788299563762}. Best is trial 44 with value: 0.8026199598993928.
# [I 2026-02-07 17:44:56,751] Trial 45 finished with value: 0.7990670116474476 and parameters: {'n_estimators': 1008, 'max_depth': 7, 'learning_rate': 0.02458209696755996, 'subsample': 0.6525999306965915, 'colsample_bytree': 0.40561954783481247, 'min_child_samples': 29, 'reg_alpha': 0.31838177940369194, 'reg_lambda': 1.661995326332974, 'num_leaves': 46, 'health_weight': 1.5734344556275925, 'pseudo_weight': 0.6383149753184106}. Best is trial 44 with value: 0.8026199598993928.
# [I 2026-02-07 17:45:01,783] Trial 46 finished with value: 0.7975632470494917 and parameters: {'n_estimators': 1009, 'max_depth': 7, 'learning_rate': 0.02231861565003016, 'subsample': 0.6552022878905526, 'colsample_bytree': 0.36713036564962853, 'min_child_samples': 29, 'reg_alpha': 0.3090079070445352, 'reg_lambda': 1.5680019020941716, 'num_leaves': 44, 'health_weight': 1.727173128557904, 'pseudo_weight': 0.6577296891689158}. Best is trial 44 with value: 0.8026199598993928.
# [I 2026-02-07 17:45:06,707] Trial 47 finished with value: 0.7851269390540003 and parameters: {'n_estimators': 989, 'max_depth': 7, 'learning_rate': 0.023323380710297378, 'subsample': 0.6484922732634647, 'colsample_bytree': 0.4076400129625092, 'min_child_samples': 36, 'reg_alpha': 0.34152271520732097, 'reg_lambda': 1.6453744985213825, 'num_leaves': 46, 'health_weight': 1.9010374358254403, 'pseudo_weight': 0.6611096768364326}. Best is trial 44 with value: 0.8026199598993928.
# [I 2026-02-07 17:45:10,961] Trial 48 finished with value: 0.7867770594865333 and parameters: {'n_estimators': 854, 'max_depth': 7, 'learning_rate': 0.020794972607812916, 'subsample': 0.7039057339923207, 'colsample_bytree': 0.32149370970579305, 'min_child_samples': 28, 'reg_alpha': 0.30074914336150443, 'reg_lambda': 0.8237856506611243, 'num_leaves': 50, 'health_weight': 1.7456749562035838, 'pseudo_weight': 0.8052378467191561}. Best is trial 44 with value: 0.8026199598993928.
# [I 2026-02-07 17:45:16,171] Trial 49 finished with value: 0.801142346464714 and parameters: {'n_estimators': 1107, 'max_depth': 7, 'learning_rate': 0.025588143935231875, 'subsample': 0.5574072692308509, 'colsample_bytree': 0.33159155660276207, 'min_child_samples': 29, 'reg_alpha': 0.585064245348058, 'reg_lambda': 1.6798961318057124, 'num_leaves': 46, 'health_weight': 1.5067073847018644, 'pseudo_weight': 0.6625573233949955}. Best is trial 44 with value: 0.8026199598993928.
# [I 2026-02-07 17:45:20,651] Trial 50 finished with value: 0.7980265852858073 and parameters: {'n_estimators': 651, 'max_depth': 7, 'learning_rate': 0.025555073759181365, 'subsample': 0.5625336826870422, 'colsample_bytree': 0.6265551245476005, 'min_child_samples': 31, 'reg_alpha': 0.6431347820293594, 'reg_lambda': 0.6642671031201001, 'num_leaves': 46, 'health_weight': 1.518518828006748, 'pseudo_weight': 0.6692645469354057}. Best is trial 44 with value: 0.8026199598993928.
# [I 2026-02-07 17:45:24,990] Trial 51 finished with value: 0.7939014882994149 and parameters: {'n_estimators': 552, 'max_depth': 7, 'learning_rate': 0.02585826224855224, 'subsample': 0.5682158507328539, 'colsample_bytree': 0.6219929849362583, 'min_child_samples': 30, 'reg_alpha': 0.7444913101450682, 'reg_lambda': 0.5990403609017977, 'num_leaves': 46, 'health_weight': 1.5047854021825657, 'pseudo_weight': 0.6780738352019057}. Best is trial 44 with value: 0.8026199598993928.
# [I 2026-02-07 17:45:29,974] Trial 52 finished with value: 0.7938176573769785 and parameters: {'n_estimators': 676, 'max_depth': 7, 'learning_rate': 0.024982422583495187, 'subsample': 0.6626996889064918, 'colsample_bytree': 0.6514877872037509, 'min_child_samples': 26, 'reg_alpha': 0.5996800551956523, 'reg_lambda': 1.7506902254840027, 'num_leaves': 44, 'health_weight': 1.6522824826166387, 'pseudo_weight': 0.5751789415877219}. Best is trial 44 with value: 0.8026199598993928.
# [I 2026-02-07 17:45:34,002] Trial 53 finished with value: 0.7833439754679665 and parameters: {'n_estimators': 807, 'max_depth': 7, 'learning_rate': 0.029117183663653543, 'subsample': 0.5535348103619007, 'colsample_bytree': 0.7277006447629114, 'min_child_samples': 36, 'reg_alpha': 0.44260791532853255, 'reg_lambda': 0.71489790573068, 'num_leaves': 41, 'health_weight': 1.7566214921005876, 'pseudo_weight': 0.6375007391916921}. Best is trial 44 with value: 0.8026199598993928.
# [I 2026-02-07 17:45:39,909] Trial 54 finished with value: 0.7975475169186355 and parameters: {'n_estimators': 1041, 'max_depth': 7, 'learning_rate': 0.016407162406518783, 'subsample': 0.5878367317259096, 'colsample_bytree': 0.5287702954825305, 'min_child_samples': 30, 'reg_alpha': 0.2603967038199523, 'reg_lambda': 1.3944661355773345, 'num_leaves': 48, 'health_weight': 1.548329301984512, 'pseudo_weight': 0.6684743363226257}. Best is trial 44 with value: 0.8026199598993928.
# [I 2026-02-07 17:45:45,761] Trial 55 finished with value: 0.7902236862372692 and parameters: {'n_estimators': 1042, 'max_depth': 5, 'learning_rate': 0.016549960357538914, 'subsample': 0.5815617492745511, 'colsample_bytree': 0.6075156783150094, 'min_child_samples': 30, 'reg_alpha': 0.2620231675393014, 'reg_lambda': 1.0874819603842036, 'num_leaves': 48, 'health_weight': 1.5332863452915773, 'pseudo_weight': 0.6615586924761856}. Best is trial 44 with value: 0.8026199598993928.
# [I 2026-02-07 17:45:51,137] Trial 56 finished with value: 0.7847561800236027 and parameters: {'n_estimators': 915, 'max_depth': 6, 'learning_rate': 0.02069628210682293, 'subsample': 0.8493414095089634, 'colsample_bytree': 0.52281286360203, 'min_child_samples': 33, 'reg_alpha': 0.5536642327756119, 'reg_lambda': 1.3580296731533819, 'num_leaves': 44, 'health_weight': 2.0370800017322708, 'pseudo_weight': 0.5685280897762854}. Best is trial 44 with value: 0.8026199598993928.
# [I 2026-02-07 17:45:56,611] Trial 57 finished with value: 0.7873226067198851 and parameters: {'n_estimators': 608, 'max_depth': 7, 'learning_rate': 0.01815977808915414, 'subsample': 0.592134569533793, 'colsample_bytree': 0.5757012123769485, 'min_child_samples': 25, 'reg_alpha': 0.32685196532660027, 'reg_lambda': 2.0667898726340237, 'num_leaves': 47, 'health_weight': 1.828965275670221, 'pseudo_weight': 0.543587057617628}. Best is trial 44 with value: 0.8026199598993928.

# %% [markdown]
# ## Evaluation

# %%
ev = evaluate(X, labels, cfg.LGB_PARAMS, cfg.HEALTH_WEIGHT, cfg.CV_FOLDS, cfg.SEED,
             X_pseudo=X_pseudo, y_pseudo=y_pseudo, pseudo_weight=cfg.PSEUDO_WEIGHT)
print(f"\nTrain F1: {ev['train_f1']:.4f}  |  Val F1: {ev['val_f1']:.4f}  |  Gap: {ev['train_f1'] - ev['val_f1']:.4f}")
print(classification_report(labels, ev["preds"], target_names=list(cfg.CLASSES)))

# %% [markdown]
# ## Test Prediction & Submission

# %%
clf, sc = train_final(X, labels, cfg, X_pseudo=X_pseudo, y_pseudo=y_pseudo)

test_names = [s["name"] for s in test_samples]
sub = predict(clf, sc, X_test, test_names, cfg)

os.makedirs(cfg.OUT_DIR, exist_ok=True)
sub_path = os.path.join(cfg.OUT_DIR, "submission.csv")
sub.to_csv(sub_path, index=False)
print(f"\nSaved {sub_path} ({len(sub)} rows)")
print(sub["Category"].value_counts())
